# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/Clustering/blob/master/gmm_exercise_mnistDigits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
# Last amended: 25th April, 2021
# Exercise: Generate handwritten digits using gaussian mixture modeling 
#
#
"""

# %% [markdown]
# ### Call libraries

# %%
# 1.0 Call libraries
from sklearn.datasets import load_digits
# 1.1 Import GaussianMixture class
from sklearn.mixture import GaussianMixture
# 1.2 Data manipulation
import pandas as pd
import numpy as np
# 1.3 Plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
# 1.4
import time, os

# %%
# 1.1 Display multiple commands output from a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### MNIST digits

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2.1 Get mnist-data
data, target = load_digits(return_X_y = True)

# %%
# 2.1.1 About data
data.shape  # (1797,64)==> 1797 images of handwitten-digits
print()
data[0]     # pixel intensities for 0th row
print()
target[:15] # Digits in first 15 rows

# %%
# 2.2 Show images of data
_=imshow(data[0].reshape(8,8))
print("The image is of digit: ",target[0])

# %%
# 2.3
_=imshow(data[111].reshape(8,8))
print("The image is of digit: ",target[111])

# %% [markdown]
# ### Perform GMM

# %%
# 3.1 Instantiate GMM class
gm_digits = GaussianMixture(
                           n_components = ZZZ , # Decide ZZZ by yourself
                           n_init = 10,
                           max_iter = 100
                         )

# %% [markdown]
# ####### Here onwards write your code and let me see digits generated by you ###########
