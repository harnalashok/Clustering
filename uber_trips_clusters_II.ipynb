# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/Clustering/blob/master/uber_trips_clusters_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Students Exercise Solution:

Last amended: 23rd May, 2022
My folder: D:\data\OneDrive\Documents\uber
           /home/ashok/Documents/4.clustering
           
DataSource:
             https://github.com/fivethirtyeight/uber-tlc-foil-response/tree/master/uber-trip-data   
             https://github.com/caroljmcdonald/spark-ml-kmeans-uber  
                   

Ref: knuggets 
    https://www.kdnuggets.com/2020/07/clustering-rideshare-data-uber.html
    Aurelion Book: https://github.com/ageron/handson-ml2/blob/master/09_unsupervised_learning.ipynb


Refere file:   uber_trips_clusters_I in github; 

Students Exercise: Discover whether uber-taxi hubs will change 
                   during office hours and non-office hours; 
                   Assume six clusters for both of them

"""

# %% [markdown]
# # Problem
# Uber Technologies Inc. is a peer-to-peer ride sharing platform. Uber's platform connects the drivers who can drive to a customer's location. Uber uses machine learning, for calculating pricing to finding the optimal positioning of cars to maximizing profits. We have used the public Uber trip dataset to discuss building a real-time example for analysis and monitoring of car GPS data.
#
# The Uber trip dataset contains data generated by Uber from New York City. The data is freely available on [FiveThirtyEight](https://data.fivethirtyeight.com/).

# %% [markdown]
# ### Software install & Call libraries

# %%
# 0.1 IF not correct versions, 
#     install desied versions
# !pip install yellowbrick==1.4
# !pip install folium==0.12.1

# %%
# 1.0 Call libraries
# %reset -f
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# 1.1 Visualization
import matplotlib.pyplot as plt
# conda install -c conda-forge folium

import folium
# conda install -c districtdatalabs yellowbrick
#from yellowbrick.cluster import SilhouetteVisualizer
#from yellowbrick.cluster import silhouette_visualizer

# 1.2
import os,time,gc

# %%
# 1.3 Let therebe display from multiple commands
#     from a jupyter cell:

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 1.4 Check
import yellowbrick
yellowbrick.__version__   # 1.4

# 1.4.1
import folium
folium.__version__        # 0.12.1
# Out:
# '1.4'
# '0.12.1'

# %%
# 1.5 Connect to your google drive
#     Transfer rossmann files from 
#     gdrive to colab VM

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2.0 Read data:

#pathToFolder = "D:\\data\\OneDrive\\Documents\\uber"
pathToFolder = "/content/drive/MyDrive/Colab_data_files/uber"
os.chdir(pathToFolder)
os.listdir(pathToFolder)
# Out:
# ['uber_raw_data_apr_sep2014.csv.zip', 'clus_mem.npy']

# %% [markdown]
# ### Read data

# %%
# 2.1 

data = pd.read_csv(
                     "uber_raw_data_apr_sep2014.csv.zip",
                     names =["dtime","lat","long","base"],
                     parse_dates = ['dtime']                     # MAke dtype of dtime as datetime
                   )

# 2.1.1 About data:

data.shape    # (45,34,327, 4)
data.head()
data.dtypes
# Out:
# (4534327, 4)
#                 dtime      lat     long    base
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512
# dtime    datetime64[ns]
# lat             float64
# long            float64
# base             object
# dtype: object

# %% [markdown]
# The dataset has 45 lakh observations and four columns. It has four attributes:
#
# > **Date/Time:** The date and time of the Uber pickup.<br>
# **Lat(Latitude)**: The latitude of the Uber pickup<br>
# **Lon(Longitude)**: The longitude of the Uber pickup.<br>
# **Base**: the TLC base company code affiliated with the Uber pickup. <br>

# %%
# 2.2 Take a sample of data:
data = data.sample(n = 100000)

# %%
# 2.3 Parse dates. We just want 'hours':

data['hour'] = data['dtime'].dt.hour

# %%
# 2.4 Divide date into day-wise periods:

data['period'] = pd.cut(
                       data['hour'],
                       bins = [-1, 7, 11, 16, 24 ],
                       labels = ['earlymorning', 'officetime', 'slacktime', 'evening']
                     )


# 2.5 Delete 'hour' column
#      and release memory:

del data['hour']
gc.collect()
# Out:
# 129

# %%
# 3.0 Group data by 'hour'
grpd = data.groupby(['period'])

# %%
# 3.1 And extract data subsets by period:

df = []
tperiod = []
for i,j in grpd:
    tperiod.append(i)
    df.append(j)

# %%
# 3.2 Here are two subsets
df[0].head()
df[1].head()
print()
tperiod[0], tperiod[1]
# Out:
#                       dtime      lat     long    base        period
# 1473687 2014-06-28 05:22:00  40.7380 -73.9851  B02598  earlymorning
# 2084890 2014-07-23 07:12:00  40.7665 -73.9158  B02598  earlymorning
# 2636686 2014-07-27 01:03:00  40.7257 -73.9512  B02682  earlymorning
# 3898696 2014-09-10 06:22:00  40.7496 -73.9815  B02617  earlymorning
# 1737230 2014-06-10 07:59:00  40.6843 -73.9961  B02682  earlymorning
#                       dtime      lat     long    base      period
# 1309871 2014-06-08 08:01:00  40.6830 -73.9811  B02598  officetime
# 2832560 2014-08-17 08:04:00  40.7218 -73.9957  B02598  officetime
# 3246204 2014-08-28 11:32:00  40.7579 -73.9677  B02617  officetime
# 635847  2014-05-05 11:17:00  40.7621 -73.9740  B02598  officetime
# 458731  2014-04-18 11:22:00  40.7192 -73.9897  B02682  officetime
# ('earlymorning', 'officetime')

# %%
# 4.0 We need only two columns
#     to perform clustering:
#     Take 400000 rows if you have small RAM
#     clus is a copy of data.

clus =  df[0][["lat","long"]]    # For earlymorning
clus1 = df[1][["lat", "long"]]   # For office hours

# %%
# 4.1 Quickly create clustering models for both periods:

# 4.2 Instantiate class with parameter values
model = KMeans(
               n_clusters = 6,
               max_iter = 300
               )

# 4.3 Train the obkect on data:

model.fit(clus)
# Out:
# KMeans(n_clusters=6)

# %%
# 4.4 Instantiate class with parameter values
model1 = KMeans(
               n_clusters = 6,
               max_iter = 300
               )

# 4.5 Train the obkect on data:

model1.fit(clus1)
# Out:
# KMeans(n_clusters=6)

# %% [markdown]
# #### Centroids

# %%
# 4.6 Where are cluster centers?

print("--Early morning\n")
model.cluster_centers_ 
print("\n--Office hours")
model1.cluster_centers_
# Out:
# --Early morning
# array([[ 40.67064758, -73.79219079],
#        [ 40.73669062, -73.9943287 ],
#        [ 40.84531077, -73.58533846],
#        [ 40.78249563, -73.95300167],
#        [ 40.68988042, -73.96086635],
#        [ 40.70012353, -74.21555529]])
# --Office hours
# array([[ 40.73338935, -73.99562313],
#        [ 40.77170865, -73.96808687],
#        [ 40.79585347, -73.87000193],
#        [ 40.6799099 , -73.75493652],
#        [ 40.69864593, -74.19764593],
#        [ 40.68683583, -73.96349024]])

# %% [markdown]
# #### SSE: Sum of squared Errors

# %%
# 4.7 What is the sum of squares from each pt to respective cluster center?

model.inertia_   # Around 1212
print()
model1.inertia_
# Out:
# 21.872902041727762
# 17.011977889914768

# %% [markdown]
# #### Show Cluster centers on folium map
# Steps:
# * Get latitude and longitude where map will be centered
# * Draw folium map with only the above location parameters
# * Add, one by one, <i>markers</i> to map. Each marker specifies <i>(lat,long)</i>
# * Optionally, specify what to display when a marker is clicked

# %%
# 5.0 Centroids for the two periods?

centroids = model.cluster_centers_
centroids1 = model1.cluster_centers_

# %%
# 5.1 Transform  cluster-centroids to a DataFrame:
clocation = pd.DataFrame(
                         centroids,
                         columns = ["Latitude", "Longitude"]
                         )

# 5.2
clocation

# 5.3
clocation1 = pd.DataFrame(
                         centroids1,
                         columns = ["Latitude", "Longitude"]
                         )

# 5.4
clocation1
# Out:
#     Latitude  Longitude
# 0  40.670648 -73.792191
# 1  40.736691 -73.994329
# 2  40.845311 -73.585338
# 3  40.782496 -73.953002
# 4  40.689880 -73.960866
# 5  40.700124 -74.215555
#     Latitude  Longitude
# 0  40.733389 -73.995623
# 1  40.771709 -73.968087
# 2  40.795853 -73.870002
# 3  40.679910 -73.754937
# 4  40.698646 -74.197646
# 5  40.686836 -73.963490

# %%
# 5.5 What are mean centroid values in each case
#      Our drawn maps will be centerd 
#      at this point:

# 5.5.1 Earlymorning
lat_mean = clocation['Latitude'].mean()
long_mean = clocation['Longitude'].mean()

# 5.5.2 Office time
lat_mean1 = clocation1['Latitude'].mean()
long_mean1 = clocation1['Longitude'].mean()

# %%
# 5.3 Converting two centroid DataFrames into lists:

centroid = clocation.values.tolist()
centroid1 = clocation1.values.tolist()

# %%
# 6.0  Plotting the centroids on google map using Folium library
#      Just specify the location of pt where map will be centered

# Early morning
map = folium.Map( location=[lat_mean,long_mean] ) # Center the map here.

# Office time
map1 = folium.Map( location=[lat_mean,long_mean] ) # Center the map here.


# 6.1 Add markers at each centroid on the map: 
#       https://python-visualization.github.io/folium/quickstart.html#Markers

# Early morning
tooltip = "Taxi hub-earlymorning"
for point in range(0, len(centroid)):
    abc=folium.Marker(
                      location =    centroid[point],             # Where to draw on the map
                      tooltip  =    tooltip +": " + str(point),  # What to display when mouse hovers on marker
                      popup    =    centroid[point]              # What to display when you click on marker
                      ).add_to(map)  
    

# Office time    
tooltip1 = "Taxi hub--Office hours"
for point in range(0, len(centroid)):
    abc=folium.Marker(
                      location =    centroid1[point],             # Where to draw on the map
                      tooltip  =    tooltip1 +": " + str(point),  # What to display when mouse hovers on marker
                      popup    =    centroid1[point]              # What to display when you click on marker
                      ).add_to(map1)

# %%
# 6.2 Draw google map
#      Early morning
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b01033b507df441eb829b64b16647769 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b01033b507df441eb829b64b16647769&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b01033b507df441eb829b64b16647769 = L.map(
#                 &quot;map_b01033b507df441eb829b64b16647769&quot;,
#                 {
#                     center: [40.73752476007132, -73.91688021075508],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60a5b48810a4024ec9d928c7609e592d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b01033b507df441eb829b64b16647769);
#
#
#             var marker_96fb224fcef680fd1c87c140eb38b3b1 = L.marker(
#                 [40.67064758308157, -73.79219078549849],
#                 {}
#             ).addTo(map_b01033b507df441eb829b64b16647769);
#
#
#         var popup_e704d0be240e9646d53e8ff969b0a4a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3988b3a68595008a2e5f51065b5f5c96 = $(`&lt;div id=&quot;html_3988b3a68595008a2e5f51065b5f5c96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.67064758308157, -73.79219078549849]&lt;/div&gt;`)[0];
#             popup_e704d0be240e9646d53e8ff969b0a4a3.setContent(html_3988b3a68595008a2e5f51065b5f5c96);
#
#
#         marker_96fb224fcef680fd1c87c140eb38b3b1.bindPopup(popup_e704d0be240e9646d53e8ff969b0a4a3)
#         ;
#
#
#
#
#             marker_96fb224fcef680fd1c87c140eb38b3b1.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub-earlymorning: 0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1d692052fcc37934bcc084cd9a00db6b = L.marker(
#                 [40.736690622454915, -73.99432870273415],
#                 {}
#             ).addTo(map_b01033b507df441eb829b64b16647769);
#
#
#         var popup_6b64130999cd0a9f84fdb69d486e89e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_77b68f60bf4525d4ce48663f056acdc5 = $(`&lt;div id=&quot;html_77b68f60bf4525d4ce48663f056acdc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.736690622454915, -73.99432870273415]&lt;/div&gt;`)[0];
#             popup_6b64130999cd0a9f84fdb69d486e89e7.setContent(html_77b68f60bf4525d4ce48663f056acdc5);
#
#
#         marker_1d692052fcc37934bcc084cd9a00db6b.bindPopup(popup_6b64130999cd0a9f84fdb69d486e89e7)
#         ;
#
#
#
#
#             marker_1d692052fcc37934bcc084cd9a00db6b.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub-earlymorning: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cbce61fe6d1e34c6329dd145b3988b50 = L.marker(
#                 [40.84531076923077, -73.58533846153846],
#                 {}
#             ).addTo(map_b01033b507df441eb829b64b16647769);
#
#
#         var popup_039a73988f25c9facebe2fb9f6b8f39a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_eb6e5ca2d6b3d6dcbd2c494348eed3b8 = $(`&lt;div id=&quot;html_eb6e5ca2d6b3d6dcbd2c494348eed3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.84531076923077, -73.58533846153846]&lt;/div&gt;`)[0];
#             popup_039a73988f25c9facebe2fb9f6b8f39a.setContent(html_eb6e5ca2d6b3d6dcbd2c494348eed3b8);
#
#
#         marker_cbce61fe6d1e34c6329dd145b3988b50.bindPopup(popup_039a73988f25c9facebe2fb9f6b8f39a)
#         ;
#
#
#
#
#             marker_cbce61fe6d1e34c6329dd145b3988b50.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub-earlymorning: 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e091f8e449dada93a777c8a61a25f4f0 = L.marker(
#                 [40.78249563351842, -73.95300166582534],
#                 {}
#             ).addTo(map_b01033b507df441eb829b64b16647769);
#
#
#         var popup_b266cd7cb4cbb522bb82e3d09b25a43c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_464231c5aab19f2fb97dbf68e1c56207 = $(`&lt;div id=&quot;html_464231c5aab19f2fb97dbf68e1c56207&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.78249563351842, -73.95300166582534]&lt;/div&gt;`)[0];
#             popup_b266cd7cb4cbb522bb82e3d09b25a43c.setContent(html_464231c5aab19f2fb97dbf68e1c56207);
#
#
#         marker_e091f8e449dada93a777c8a61a25f4f0.bindPopup(popup_b266cd7cb4cbb522bb82e3d09b25a43c)
#         ;
#
#
#
#
#             marker_e091f8e449dada93a777c8a61a25f4f0.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub-earlymorning: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_

# %%
# Office hour
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10672ba5f8aed18a3c6ddc8588342caa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10672ba5f8aed18a3c6ddc8588342caa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_10672ba5f8aed18a3c6ddc8588342caa = L.map(
#                 &quot;map_10672ba5f8aed18a3c6ddc8588342caa&quot;,
#                 {
#                     center: [40.73752476007132, -73.91688021075508],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5167d930c69e004bccdc58b5851ab241 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10672ba5f8aed18a3c6ddc8588342caa);
#
#
#             var marker_4e5f06bf60e4f8373d8d4bd268ceab80 = L.marker(
#                 [40.73338935424916, -73.99562313432835],
#                 {}
#             ).addTo(map_10672ba5f8aed18a3c6ddc8588342caa);
#
#
#         var popup_ddb8200454ee8415d68c327143ca906d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e76c16252994f1b6214df1a1193f3596 = $(`&lt;div id=&quot;html_e76c16252994f1b6214df1a1193f3596&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.73338935424916, -73.99562313432835]&lt;/div&gt;`)[0];
#             popup_ddb8200454ee8415d68c327143ca906d.setContent(html_e76c16252994f1b6214df1a1193f3596);
#
#
#         marker_4e5f06bf60e4f8373d8d4bd268ceab80.bindPopup(popup_ddb8200454ee8415d68c327143ca906d)
#         ;
#
#
#
#
#             marker_4e5f06bf60e4f8373d8d4bd268ceab80.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub--Office hours: 0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f452a0f965b8b59f161fb2d008cfe5d = L.marker(
#                 [40.77170864647239, -73.9680868673313],
#                 {}
#             ).addTo(map_10672ba5f8aed18a3c6ddc8588342caa);
#
#
#         var popup_7aebce7676d80f76a7e7025e40b22687 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_39c76b10aacd8a85411c64f4fb46a917 = $(`&lt;div id=&quot;html_39c76b10aacd8a85411c64f4fb46a917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.77170864647239, -73.9680868673313]&lt;/div&gt;`)[0];
#             popup_7aebce7676d80f76a7e7025e40b22687.setContent(html_39c76b10aacd8a85411c64f4fb46a917);
#
#
#         marker_7f452a0f965b8b59f161fb2d008cfe5d.bindPopup(popup_7aebce7676d80f76a7e7025e40b22687)
#         ;
#
#
#
#
#             marker_7f452a0f965b8b59f161fb2d008cfe5d.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub--Office hours: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dabce8e783e16550ae19f249947abbed = L.marker(
#                 [40.79585347043702, -73.87000192802057],
#                 {}
#             ).addTo(map_10672ba5f8aed18a3c6ddc8588342caa);
#
#
#         var popup_95c2183474938e58c293fb89aaa66f1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3922b450a609a5edceecaa9c061870fc = $(`&lt;div id=&quot;html_3922b450a609a5edceecaa9c061870fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.79585347043702, -73.87000192802057]&lt;/div&gt;`)[0];
#             popup_95c2183474938e58c293fb89aaa66f1f.setContent(html_3922b450a609a5edceecaa9c061870fc);
#
#
#         marker_dabce8e783e16550ae19f249947abbed.bindPopup(popup_95c2183474938e58c293fb89aaa66f1f)
#         ;
#
#
#
#
#             marker_dabce8e783e16550ae19f249947abbed.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub--Office hours: 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1913b70950f76e4d39df14597925662f = L.marker(
#                 [40.67990989761092, -73.75493651877133],
#                 {}
#             ).addTo(map_10672ba5f8aed18a3c6ddc8588342caa);
#
#
#         var popup_54b8eac13984ea6dd2794e886dd1a04f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_65c42600bdffbfc07dcedf810068828b = $(`&lt;div id=&quot;html_65c42600bdffbfc07dcedf810068828b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.67990989761092, -73.75493651877133]&lt;/div&gt;`)[0];
#             popup_54b8eac13984ea6dd2794e886dd1a04f.setContent(html_65c42600bdffbfc07dcedf810068828b);
#
#
#         marker_1913b70950f76e4d39df14597925662f.bindPopup(popup_54b8eac13984ea6dd2794e886dd1a04f)
#         ;
#
#
#
#
#             marker_1913b70950f76e4d39df14597925662f.bindTooltip(
#                 `&lt;div&gt;
#                      Taxi hub--Office hours: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_

# %%
####### I am done ################
